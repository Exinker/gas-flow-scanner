# %%
import matplotlib.cm as cm

from scanner.data import Data
from scanner.device import Device, DeviceConfig

# %%
device = Device(
    config=DeviceConfig(
        omega=100,
        tau=2,
    ),
)

# %%
# calibrate to dark

device.calibrate_dark()

# %%
# runtime view data (bloking)

# device.view()

# %%
# read data

data = device.read(
    exposure=3_500,  # in ms
    xoffset=10,
    xscale=1,
    zoffset=10,
    zscale=1,
)


# save to .pkl file
data.save()

# %%
# show data

data.show(
    clim=(0, 100),
    cmap=cm.coolwarm,
)

# %%
# show slices

data.graph(
    x0=11.5,
)
data.graph(
    z0=14.8,
)

# %%
# load from binary file

filename = '24.03.29 14.02.32.pkl'
data = Data.load(f'data/{filename}')
